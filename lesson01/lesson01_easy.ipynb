# %%
__author__ = 'Алексей Сидорюк'

# Задача-1: Дано произвольное целое число (число заранее неизвестно).
# Вывести поочередно цифры исходного числа (порядок вывода цифр неважен).
# Подсказки:
# * постарайтесь решить задачу с применением арифметики и цикла while;
# * при желании решите задачу с применением цикла for.

number_str = input('Введите целое число: ')

# 1.
i = 0
while i < len(number_str):
    print(number_str[i], end=' ')
    i += 1
print('\n')

# 2.
number_int = int(number_str)
i = 0
while (number_int >= number_int % 10**(i + 1)) & (number_int % 10**(i + 1) // 10**i != 0) :
    print(number_int % 10**(i + 1) // 10**i, end=' ')
    i += 1
print('\n')

# 3.
for i in number_str:
    print(i, end=' ')
print('\n')


# Задача-2: Исходные значения двух переменных запросить у пользователя.
# Поменять значения переменных местами. Вывести новые значения на экран.
# Подсказка:
# * постарайтесь сделать решение через дополнительную переменную 
#   или через арифметические действия
# Не нужно решать задачу так:
# print("a = ", b, "b = ", a) - это неправильное решение!

a = input('Введите значение первой переменной a: ')
b = input('Введите значение второй переменной b: ')
c = b
b = a
a = c
print('В a теперь ', a, ', а в b теперь ', b, '\n')


# Задача-3: Запросите у пользователя его возраст.
# Если ему есть 18 лет, выведите: "Доступ разрешен",
# иначе "Извините, пользование данным ресурсом только с 18 лет"

age_str = input('Сколько вам лет? ')

# 1.
if int(age_str) >= 18:
    print('Доступ разрешен\n')
else:
    print('Извините, пользование данным ресурсом только с 18 лет\n')

# 2.
print('Доступ разрешен\n') if int(input('Сколько вам лет? ')) > 18 else print('Извините, пользование данным ресурсом только с 18 лет\n')
